# %%
import pandas as pd
import numpy as np
import os
import sys

import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import IPython.display as ipd
from IPython.display import Audio
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization , GRU
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD



import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
import tensorflow as tf
print ("Done")
# Out:
# Done

# %%
# !apt-get install libsndfile1
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libsndfile1 is already the newest version (1.0.31-2ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %% [markdown]
# # Importing Data

# %%
os.environ['KAGGLE_CONFIG_DIR'] = '/content'
# !kaggle datasets download -d uwrfkaggler/ravdess-emotional-speech-audio
# !unzip ravdess-emotional-speech-audio.zip -d ravdess

# !kaggle datasets download -d ejlok1/cremad
# !unzip cremad.zip -d cremad

# !kaggle datasets download -d ejlok1/toronto-emotional-speech-set-tess
# !unzip toronto-emotional-speech-set-tess.zip -d Tess
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_back_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bar_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_base_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bath_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bean_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_beg_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bite_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_boat_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bone_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_book_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bought_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_burn_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_cab_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_calm_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_came_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_cause_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_chain_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_chair_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_chalk_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_chat_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_check_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_cheek_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_chief_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_choice_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_cool_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_dab_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_date_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_dead_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_death_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_deep_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_dime_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_dip_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_ditch_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_dodge_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_dog_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_doll_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_door_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_fail_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_fall_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_far_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_fat_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_fit_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_five_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_food_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_gap_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_gas_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_gaze_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_germ_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_get_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_gin_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_goal_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_good_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_goose_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_gun_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_half_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_hall_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_hash_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_hate_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF
ess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_life_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_limb_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_live_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_loaf_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_long_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_lore_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_lose_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_lot_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_love_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_luck_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_make_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_match_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_merge_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mess_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_met_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mill_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mob_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mode_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mood_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_moon_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mop_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mouse_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_nag_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_name_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_near_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_neat_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_nice_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_note_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_numb_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pad_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_page_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pain_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pass_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pearl_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_peg_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_perch_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_phone_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pick_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pike_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pole_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pool_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_puff_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rag_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_raid_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rain_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_raise_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rat_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_reach_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_read_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_red_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_ring_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_ripe_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_road_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_room_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rose_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rot_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rough_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rush_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_said_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sail_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_search_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_seize_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sell_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shack_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shall_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shawl_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sheep_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shirt_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_should_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shout_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_size_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_soap_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_soup_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sour_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_south_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sub_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_such_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sure_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_take_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_talk_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tape_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_team_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tell_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_thin_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_third_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_thought_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_thumb_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_time_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tip_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tire_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_ton_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tool_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tough_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_turn_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_vine_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_voice_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_void_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_vote_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wag_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_walk_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wash_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_week_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wheat_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_when_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_which_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_whip_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_white_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wife_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wire_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_witch_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_yearn_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_yes_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_young_sad.wav
#   inflating: Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_youth_sad.wav

# %% [markdown]
# Streaming output truncated to the last 5000 lines.
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_back_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bar_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_base_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bath_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bean_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_beg_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bite_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_boat_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bone_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_book_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bought_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_burn_angry.wav
#   inflating: Tess/TESS Toronto emotional speech set data/OAF_angry/OAF_cab_angry.wav

# %%
ravdess = "/content/ravdess/audio_speech_actors_01-24/"
Crema = "/content/cremad/AudioWAV/"
Tess = "/content/Tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/"

# %% [markdown]
# # Preprocessing

# %% [markdown]
# **Ravdees**

# %%
file_emotion = []
file_path = []
ravdess_directory_list = os.listdir(ravdess)
for i in ravdess_directory_list:
    # as their are 24 different actors in our previous directory we need to extract files for each actor.
    actor = os.listdir(ravdess + i)
    for f in actor:
        part = f.split('.')[0].split('-')
    # third part in each file represents the emotion associated to that file.
        file_emotion.append(int(part[2]))
        file_path.append(ravdess + i + '/' + f)

# %%
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])
# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
ravdess_df = pd.concat([emotion_df, path_df], axis=1)
# changing integers to actual emotions.
ravdess_df.Emotions.replace({1:'neutral', 2:'neutral', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust',
                             8:'surprise'},
                            inplace=True)
print(ravdess_df.head())
print("______________________________________________")
print(ravdess_df.tail())
print("_______________________________________________")
print(ravdess_df.Emotions.value_counts())
# Out:
#   Emotions                                               Path
# 0      sad  /content/ravdess/audio_speech_actors_01-24/Act...
# 1  neutral  /content/ravdess/audio_speech_actors_01-24/Act...
# 2    happy  /content/ravdess/audio_speech_actors_01-24/Act...
# 3  neutral  /content/ravdess/audio_speech_actors_01-24/Act...
# 4    angry  /content/ravdess/audio_speech_actors_01-24/Act...
# ______________________________________________
#      Emotions                                               Path
# 1435    happy  /content/ravdess/audio_speech_actors_01-24/Act...
# 1436     fear  /content/ravdess/audio_speech_actors_01-24/Act...
# 1437      sad  /content/ravdess/audio_speech_actors_01-24/Act...
# 1438  disgust  /content/ravdess/audio_speech_actors_01-24/Act...
# 1439      sad  /content/ravdess/audio_speech_actors_01-24/Act...
# _______________________________________________
# Emotions
# neutral     288
# sad         192
# happy       192
# angry       192
# fear        192
# surprise    192
# disgust     192
# Name: count, dtype: int64

# %% [markdown]
# **Crema DataFrame**

# %%
crema_directory_list = os.listdir(Crema)

file_emotion = []
file_path = []

for file in crema_directory_list:
    # storing file paths
    file_path.append(Crema + file)
    # storing file emotions
    part=file.split('_')
    if part[2] == 'SAD':
        file_emotion.append('sad')
    elif part[2] == 'ANG':
        file_emotion.append('angry')
    elif part[2] == 'DIS':
        file_emotion.append('disgust')
    elif part[2] == 'FEA':
        file_emotion.append('fear')
    elif part[2] == 'HAP':
        file_emotion.append('happy')
    elif part[2] == 'NEU':
        file_emotion.append('neutral')
    else:
        file_emotion.append('Unknown')

# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Crema_df = pd.concat([emotion_df, path_df], axis=1)
Crema_df.head()
print(Crema_df.Emotions.value_counts())
# Out:
# Emotions
# happy      1271
# angry      1271
# sad        1271
# fear       1271
# disgust    1271
# neutral    1087
# Name: count, dtype: int64

# %% [markdown]
# **TESS dataset**

# %%
tess_directory_list = os.listdir(Tess)

file_emotion = []
file_path = []

for dir in tess_directory_list:
    directories = os.listdir(Tess + dir)
    for file in directories:
        part = file.split('.')[0]
        part = part.split('_')[2]
        if part=='ps':
            file_emotion.append('surprise')
        else:
            file_emotion.append(part)
        file_path.append(Tess + dir + '/' + file)

# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Tess_df = pd.concat([emotion_df, path_df], axis=1)
Tess_df.head()
print(Tess_df.Emotions.value_counts())
# Out:
# Emotions
# happy       400
# fear        400
# sad         400
# angry       400
# disgust     400
# neutral     400
# surprise    400
# Name: count, dtype: int64

# %% [markdown]
# # Integration

# %%
data_path = pd.concat([ravdess_df, Crema_df, Tess_df], axis = 0)
data_path.to_csv("data_path.csv",index=False)
data_path.head()
# Out:
#   Emotions                                               Path
# 0      sad  /content/ravdess/audio_speech_actors_01-24/Act...
# 1  neutral  /content/ravdess/audio_speech_actors_01-24/Act...
# 2    happy  /content/ravdess/audio_speech_actors_01-24/Act...
# 3  neutral  /content/ravdess/audio_speech_actors_01-24/Act...
# 4    angry  /content/ravdess/audio_speech_actors_01-24/Act...

# %%
print(data_path.Emotions.value_counts())
# Out:
# Emotions
# sad         1863
# happy       1863
# angry       1863
# fear        1863
# disgust     1863
# neutral     1775
# surprise     592
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualisation and Exploration

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.title('Count of Emotions', size=16)
sns.countplot(data = data_path, x='Emotions')
plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
data,sr = librosa.load(file_path[0])
sr
# Out:
# 22050

# %%
ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(10, 5))
spectrogram = librosa.feature.melspectrogram(y=data, sr=sr, n_mels=128,fmax=8000)
log_spectrogram = librosa.power_to_db(spectrogram)
librosa.display.specshow(log_spectrogram, y_axis='mel', sr=sr, x_axis='time');
plt.title('Mel Spectrogram ')
plt.colorbar(format='%+2.0f dB')

# %%
mfcc = librosa.feature.mfcc(y=data, sr=sr, n_mfcc=30)


# MFCC
plt.figure(figsize=(16, 10))
plt.subplot(3,1,1)
librosa.display.specshow(mfcc, x_axis='time')
plt.ylabel('MFCC')
plt.colorbar()

ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Data augmentation

# %%
# NOISE
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

# STRETCH
def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate = rate)
# SHIFT
def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)
# PITCH
def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sr = sampling_rate, n_steps = pitch_factor)

# %%
# NORMAL AUDIO


import librosa.display
plt.figure(figsize=(12, 5))
librosa.display.waveshow(y=data, sr=sr)
ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# AUDIO WITH NOISE
x = noise(data)
plt.figure(figsize=(12,5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# STRETCHED AUDIO
x = stretch(data)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# SHIFTED AUDIO
x = shift(data)
plt.figure(figsize=(12,5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# AUDIO WITH PITCH
x = pitch(data, sr)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Feature extraction

# %%
def zcr(data,frame_length,hop_length):
    zcr=librosa.feature.zero_crossing_rate(data,frame_length=frame_length,hop_length=hop_length)
    return np.squeeze(zcr)
def rmse(data,frame_length=2048,hop_length=512):
    rmse=librosa.feature.rms(y=data,frame_length = frame_length,hop_length = hop_length)
    return np.squeeze(rmse)
def mfcc(data,sr,frame_length=2048,hop_length=512,flatten:bool=True):
    mfcc=librosa.feature.mfcc(y=data,sr=sr)
    return np.squeeze(mfcc.T)if not flatten else np.ravel(mfcc.T)

def extract_features(data,sr=22050,frame_length=2048,hop_length=512):
    result=np.array([])

    result=np.hstack((result,
                      zcr(data,frame_length,hop_length),
                      rmse(data,frame_length,hop_length),
                      mfcc(data,sr,frame_length,hop_length)
                     ))
    return result

def get_features(path,duration=2.5, offset=0.6):
    data,sr=librosa.load(path,duration=duration,offset=offset)
    aud=extract_features(data)
    audio=np.array(aud)

    noised_audio=noise(data)
    aud2=extract_features(noised_audio)
    audio=np.vstack((audio,aud2))

    pitched_audio=pitch(data,sr)
    aud3=extract_features(pitched_audio)
    audio=np.vstack((audio,aud3))

    pitched_audio1=pitch(data,sr)
    pitched_noised_audio=noise(pitched_audio1)
    aud4=extract_features(pitched_noised_audio)
    audio=np.vstack((audio,aud4))

    return audio

# %%
import multiprocessing as mp
print("Number of processors: ", mp.cpu_count())
# Out:
# Number of processors:  8

# %%
import timeit
from tqdm import tqdm
start = timeit.default_timer()
X,Y=[],[]
for path,emotion,index in tqdm (zip(data_path.Path,data_path.Emotions,range(data_path.Path.shape[0]))):
    features=get_features(path)
    if index%500==0:
        print(f'{index} audio has been processed')
    for i in features:
        X.append(i)
        Y.append(emotion)
print('Done')
stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# 2it [00:00,  6.79it/s]
# 0 audio has been processed
# 502it [01:13,  7.14it/s]
# 500 audio has been processed
# 1002it [02:27,  6.80it/s]
# 1000 audio has been processed
# 1502it [03:40,  7.58it/s]
# 1500 audio has been processed
# 2002it [04:40,  8.27it/s]
# 2000 audio has been processed
# 2502it [05:39,  7.64it/s]
# 2500 audio has been processed
# 3001it [06:38,  8.50it/s]
# 3000 audio has been processed
# 3502it [07:37,  8.59it/s]
# 3500 audio has been processed
# 4002it [08:37,  8.57it/s]
# 4000 audio has been processed
# 4503it [09:38,  9.16it/s]
# 4500 audio has been processed
# 5001it [10:38,  8.16it/s]
# 5000 audio has been processed
# 5502it [11:38,  8.67it/s]
# 5500 audio has been processed
# 6001it [12:39,  8.70it/s]
# 6000 audio has been processed
# 6502it [13:39,  8.78it/s]
# 6500 audio has been processed
# 7002it [14:40,  7.94it/s]
# 7000 audio has been processed
# 7502it [15:41,  8.90it/s]
# 7500 audio has been processed
# 8002it [16:41,  8.42it/s]
# 8000 audio has been processed
# 8503it [17:42,  8.75it/s]
# 8500 audio has been processed
# 9002it [18:39, 10.44it/s]
# 9000 audio has been processed
# 9502it [19:30, 12.65it/s]
# 9500 audio has been processed
# 10003it [20:11, 10.87it/s]
# 10000 audio has been processed
# 10503it [21:06, 10.05it/s]
# 10500 audio has been processed
# 11002it [21:55, 10.74it/s]
# 11000 audio has been processed
# 11502it [22:50, 10.26it/s]
# 11500 audio has been processed
# 11682it [23:07,  8.42it/s]
# Done
# Time:  1387.9043732730001

# %%
len(X), len(Y), data_path.Path.shape
# Out:
# (46728, 46728, (11682,))

# %% [markdown]
# # Saving features

# %%
Emotions = pd.DataFrame(X)
Emotions['Emotions'] = Y
Emotions.to_csv('emotion.csv', index=False)
Emotions.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.054688  0.240234  0.402832  0.613770  0.748047  0.677734  0.598633
# 1  0.250977  0.364258  0.488770  0.487793  0.479980  0.486816  0.491211
# 2  0.008789  0.060059  0.155762  0.256348  0.339355  0.373535  0.367188
# 3  0.241699  0.364746  0.494629  0.497559  0.498047  0.493652  0.477051
# 4  0.233398  0.325195  0.348145  0.348633  0.184570  0.101074  0.096191
#
#           7         8         9  ...       2367       2368       2369  \
# 0  0.477539  0.340820  0.321777  ...   3.109422   4.065667   4.724000
# 1  0.500488  0.504883  0.505859  ...  -5.115308  -4.289678  -3.173473
# 2  0.333008  0.288086  0.269531  ...   6.033799   6.959149   6.831691
# 3  0.468750  0.470215  0.469727  ...   0.655807  -4.450074  -3.745694
# 4  0.067871  0.102051  0.118652  ...  11.385839  11.471487  10.634184
#
#        2370      2371      2372      2373      2374      2375  Emotions
# 0  4.939294  4.834435  4.586147  4.233512  3.689887  2.933530       sad
# 1  0.024235  2.036838  0.342517 -3.942147 -0.171483  3.402838       sad
# 2  6.197251  6.035901  6.691113  7.492633  7.461338  6.378284       sad
# 3  0.620662  3.872920  1.813774 -0.574342  2.924145  4.274095       sad
# 4  9.504230  8.960629  7.567750  5.296756  4.405684  4.357855   neutral
#
# [5 rows x 2377 columns]

# %%
print(Emotions.isna().any())
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 2372         True
# 2373         True
# 2374         True
# 2375         True
# Emotions    False
# Length: 2377, dtype: bool

# %%
Emotions=Emotions.fillna(0)
print(Emotions.isna().any())
Emotions.shape
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 2372        False
# 2373        False
# 2374        False
# 2375        False
# Emotions    False
# Length: 2377, dtype: bool
# (46728, 2377)

# %%
np.sum(Emotions.isna())
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 2372        0
# 2373        0
# 2374        0
# 2375        0
# Emotions    0
# Length: 2377, dtype: int64

# %% [markdown]
# # Data preparation

# %%
X = Emotions.iloc[: ,:-1].values
Y = Emotions['Emotions'].values

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
print(Y.shape)
X.shape
# Out:
# (46728, 7)
# (46728, 2376)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y,test_size=0.4, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((28036, 2376), (28036, 7), (18692, 2376), (18692, 7))

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((28036, 2376), (28036, 7), (18692, 2376), (18692, 7))

# %%
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization , GRU
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# > Applying early stopping

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
model_checkpoint = ModelCheckpoint('best_model1_weights.h5', monitor='val_accuracy', save_best_only=True)

# %%
early_stop=EarlyStopping(monitor='val_accuracy',mode='auto',patience=5,restore_best_weights=True)
lr_reduction=ReduceLROnPlateau(monitor='val_accuracy',patience=3,verbose=1,factor=0.5,min_lr=0.00001)

# %% [markdown]
# # CNN Model

# %%
#Reshape for CNN MODEL

x_traincnn =np.expand_dims(x_train, axis=2)
x_testcnn= np.expand_dims(x_test, axis=2)
x_traincnn.shape, y_train.shape, x_testcnn.shape, y_test.shape
# Out:
# ((28036, 2376, 1), (28036, 7), (18692, 2376, 1), (18692, 7))

# %%
import tensorflow.keras.layers as L

model = tf.keras.Sequential([
    L.Conv1D(512,kernel_size=5, strides=1,padding='same', activation='relu',input_shape=(x_traincnn.shape[1],1)),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),

    L.Conv1D(512,kernel_size=5,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),
    Dropout(0.2),  # Add dropout layer after the second max pooling layer

    L.Conv1D(256,kernel_size=5,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),


    L.Conv1D(128,kernel_size=3,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=3,strides=2,padding='same'),
    Dropout(0.2),  # Add dropout layer after the fifth max pooling layer

    L.Flatten(),
    L.Dense(512,activation='relu'),
    L.BatchNormalization(),
    L.Dense(7,activation='softmax')
])
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics='accuracy')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2376, 512)         3072
#
#  batch_normalization (Batch  (None, 2376, 512)         2048
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 1188, 512)         0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 1188, 512)         1311232
#
#  batch_normalization_1 (Bat  (None, 1188, 512)         2048
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 594, 512)          0
#  g1D)
#
#  dropout (Dropout)           (None, 594, 512)          0
#
#  conv1d_2 (Conv1D)           (None, 594, 256)          655616
#
#  batch_normalization_2 (Bat  (None, 594, 256)          1024
#  chNormalization)
#
#  max_pooling1d_2 (MaxPoolin  (None, 297, 256)          0
#  g1D)
#
#  conv1d_3 (Conv1D)           (None, 297, 128)          98432
#
#  batch_normalization_3 (Bat  (None, 297, 128)          512
#  chNormalization)
#
#  max_pooling1d_3 (MaxPoolin  (None, 149, 128)          0
#  g1D)
#
#  dropout_1 (Dropout)         (None, 149, 128)          0
#
#  flatten (Flatten)           (None, 19072)             0
#
#  dense (Dense)               (None, 512)               9765376
#
#  batch_normalization_4 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 11844999 (45.19 MB)
# Trainable params: 11841159 (45.17 MB)
# Non-trainable params: 3840 (15.00 KB)
# _________________________________________________________________

# %%
history=model.fit(x_traincnn, y_train, epochs=50, validation_data=(x_testcnn, y_test), batch_size=64,callbacks=[early_stop,lr_reduction,model_checkpoint])
# Out:
# Epoch 1/50
# 439/439 [==============================] - ETA: 0s - loss: 1.4155 - accuracy: 0.4683
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 439/439 [==============================] - 58s 112ms/step - loss: 1.4155 - accuracy: 0.4683 - val_loss: 1.7325 - val_accuracy: 0.3415 - lr: 0.0010
# Epoch 2/50
# 439/439 [==============================] - 48s 110ms/step - loss: 1.1077 - accuracy: 0.5699 - val_loss: 1.1284 - val_accuracy: 0.5530 - lr: 0.0010
# Epoch 3/50
# 439/439 [==============================] - 48s 110ms/step - loss: 0.9817 - accuracy: 0.6244 - val_loss: 0.9649 - val_accuracy: 0.6254 - lr: 0.0010
# Epoch 4/50
# 439/439 [==============================] - 48s 110ms/step - loss: 0.8623 - accuracy: 0.6737 - val_loss: 0.9765 - val_accuracy: 0.6258 - lr: 0.0010
# Epoch 5/50
# 439/439 [==============================] - 48s 109ms/step - loss: 0.7234 - accuracy: 0.7288 - val_loss: 0.8907 - val_accuracy: 0.6650 - lr: 0.0010
# Epoch 6/50
# 439/439 [==============================] - 48s 110ms/step - loss: 0.5996 - accuracy: 0.7780 - val_loss: 0.8252 - val_accuracy: 0.7039 - lr: 0.0010
# Epoch 7/50
# 439/439 [==============================] - 48s 109ms/step - loss: 0.4737 - accuracy: 0.8291 - val_loss: 0.9207 - val_accuracy: 0.6920 - lr: 0.0010
# Epoch 8/50
# 439/439 [==============================] - 48s 110ms/step - loss: 0.3539 - accuracy: 0.8734 - val_loss: 0.7979 - val_accuracy: 0.7282 - lr: 0.0010
# Epoch 9/50
# 439/439 [==============================] - 48s 110ms/step - loss: 0.4722 - accuracy: 0.8299 - val_loss: 0.6233 - val_accuracy: 0.7779 - lr: 0.0010
ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 439/439 [==============================] - 48s 109ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 0.3191 - val_accuracy: 0.9337 - lr: 2.5000e-04
# Epoch 45/50
# 439/439 [==============================] - 48s 109ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.3093 - val_accuracy: 0.9348 - lr: 1.2500e-04
# Epoch 46/50
# 439/439 [==============================] - 48s 109ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.3174 - val_accuracy: 0.9334 - lr: 1.2500e-04

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_testcnn,y_test)[1]*100 , "%")

epochs = [i for i in range(len(history.history['accuracy']))]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 585/585 [==============================] - 9s 14ms/step - loss: 0.3024 - accuracy: 0.9362
# Accuracy of our model on test data :  93.6229407787323 %

# %%
# predicting on test data.
pred_test0 = model.predict(x_testcnn)
y_pred0 = encoder.inverse_transform(pred_test0)
y_test0 = encoder.inverse_transform(y_test)

# Check for random predictions
df0 = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df0['Predicted Labels'] = y_pred0.flatten()
df0['Actual Labels'] = y_test0.flatten()

df0.head(10)
# Out:
# 585/585 [==============================] - 7s 12ms/step
#   Predicted Labels Actual Labels
# 0             fear          fear
# 1              sad           sad
# 2            happy          fear
# 3            angry         angry
# 4             fear          fear
# 5            angry         angry
# 6            happy         happy
# 7            angry         angry
# 8            happy         happy
# 9          disgust       disgust

# %% [markdown]
# # Evalutation

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(y_test0, y_pred0)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
#cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(cm, linecolor='white', cmap='Greens', linewidth=1, annot=True, fmt='.2f')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()
print(classification_report(y_test0, y_pred0))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.93      0.95      0.94      2959
#      disgust       0.93      0.93      0.93      3036
#         fear       0.93      0.92      0.92      3008
#        happy       0.93      0.91      0.92      3007
#      neutral       0.93      0.96      0.95      2754
#          sad       0.95      0.94      0.94      2982
#     surprise       0.97      0.96      0.96       946
#
#     accuracy                           0.94     18692
#    macro avg       0.94      0.94      0.94     18692
# weighted avg       0.94      0.94      0.94     18692

# %%
def zcr(data,frame_length,hop_length):
    zcr=librosa.feature.zero_crossing_rate(data,frame_length=frame_length,hop_length=hop_length)
    return np.squeeze(zcr)
def rmse(data,frame_length=2048,hop_length=512):
    rmse=librosa.feature.rms(y=data,frame_length=frame_length,hop_length=hop_length)
    return np.squeeze(rmse)
def mfcc(data,sr,frame_length=2048,hop_length=512,flatten:bool=True):
    mfcc=librosa.feature.mfcc(y=data,sr=sr)
    return np.squeeze(mfcc.T)if not flatten else np.ravel(mfcc.T)

def extract_features(data,sr=22050,frame_length=2048,hop_length=512):
    result=np.array([])

    result=np.hstack((result,
                      zcr(data,frame_length,hop_length),
                      rmse(data,frame_length,hop_length),
                      mfcc(data,sr,frame_length,hop_length)
                     ))
    return result

# %%
def get_predict_feat(path):
    d, s_rate= librosa.load(path=path, duration=2.5, offset=0.6)
    res=extract_features(d)
    result=np.array(res)
    result=np.reshape(result,newshape=(1,2376))
    i_result = scaler.transform(result)
    final_result=np.expand_dims(i_result, axis=2)

    return final_result

# %%
res=get_predict_feat("/content/ravdess/Actor_01/03-01-07-01-01-01-01.wav")
print(res.shape)
# Out:
# (1, 2376, 1)

# %%
emotions1={1:'Neutral', 2:'Neutral', 3:'Happy', 4:'Sad', 5:'Angry', 6:'Fear', 7:'Disgust',8:'Surprise'}
def prediction(path1):
    res=get_predict_feat(path1)
    predictions=model.predict(res)
    y_pred = encoder.inverse_transform(predictions)
    print(y_pred[0][0])

# %%
path = "/content/ravdess/Actor_02/03-01-01-01-01-01-02.wav"
prediction(path)
data,sr = librosa.load(path)
ipd.Audio(data,rate=sr)
# Out:
# 1/1 [==============================] - 0s 150ms/step
# neutral
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
path = "/content/ravdess/Actor_01/03-01-01-01-01-01-01.wav"
prediction(path)
data,sr = librosa.load(path)
ipd.Audio(data,rate=sr)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# neutral
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
path = "/content/ravdess/Actor_01/03-01-05-01-02-02-01.wav"
prediction(path)
data,sr = librosa.load(path)
ipd.Audio(data,rate=sr)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# angry
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
path = "/content/ravdess/Actor_21/03-01-04-02-02-02-21.wav"
prediction(path)
data,sr = librosa.load(path)
ipd.Audio(data,rate=sr)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# sad
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
path = "/content/ravdess/Actor_02/03-01-06-01-02-02-02.wav"
prediction(path)
data,sr = librosa.load(path)
ipd.Audio(data,rate=sr)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# fear
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
path = "/content/ravdess/Actor_01/03-01-08-01-01-01-01.wav"
prediction(path)
data,sr = librosa.load(path)
ipd.Audio(data,rate=sr)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# surprise
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
path = "/content/ravdess/Actor_01/03-01-07-01-01-01-01.wav"
prediction(path)
data,sr = librosa.load(path)
ipd.Audio(data,rate=sr)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# disgust
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
